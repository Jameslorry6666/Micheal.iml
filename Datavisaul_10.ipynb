# %% [markdown]
# <a href="https://colab.research.google.com/github/Jameslorry6666/Micheal.iml/blob/master/Datavisaul_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercise 10: Creating Bar Plots Grouped by a Specific Feature
import seaborn as sns

# %%
diamonds_df = sns.load_dataset('diamonds')
ax = sns.barplot(x="cut", y="price", hue='color', data=diamonds_df)
