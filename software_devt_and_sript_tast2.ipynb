# %% [markdown]
# <a href="https://colab.research.google.com/github/Jameslorry6666/Micheal.iml/blob/master/software_devt_and_sript_tast2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing necessary libraries
import requests
from bs4 import BeautifulSoup as Soup
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
import io
# Out:
#      <input type="file" id="files-7bb73366-d7f6-4418-995d-2fb23de501c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7bb73366-d7f6-4418-995d-2fb23de501c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
james = pd.read_csv(io.BytesIO(uploaded['ds.csv']))

# %%
r = requests.get("https://en.wikipedia.org/wiki/Six_degrees_of_separation")

# %%
print(r)
# Out:
# <Response [200]>

# %%
bsobj = Soup( r .content, 'lxml')
bsobj
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Six degrees of separation - Wikipedia</title>
# ...

# %%
for link in bsobj.findAll("h2"):
  print ("headlines : {}" .format(link.text) )
# Out:
# headlines : Contents
# headlines : Early conceptions[edit]
# headlines : Research[edit]
# headlines : Popularization[edit]
# headlines : Mathematics[edit]
# headlines : Psychology[edit]
# headlines : In popular culture[edit]
# headlines : See also[edit]
# headlines : Notes[edit]
# headlines : References[edit]
# headlines : External links[edit]

# %%
r = requests.get('https://en.wikipedia.org/wiki/Six_degrees_of_separation', allow_redirects=True)
print(r.url)
# Out:
# https://en.wikipedia.org/wiki/Six_degrees_of_separation

# %%
r = requests.get('https://en.wikipedia.org/wiki/Six_degrees_of_separation', allow_redirects=True)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Six degrees of separation - Wikipedia</title>
# ...

# %%
r = requests.head('https://en.wikipedia.org/wiki/Six_degrees_of_separation', allow_redirects=True)
print(r.url)
# Out:
# https://en.wikipedia.org/wiki/Six_degrees_of_separation
